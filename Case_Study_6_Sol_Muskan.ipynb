# %% [markdown]
# ## Python Final Capstone Project

# %%
import os
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('C:\\Users\\DELL\\Downloads\\Python Notebook\\5. Python Foundation End to End Case Study_E-Commerce Analytics Project')

# %%
geo_loc = pd.read_csv('GEO_LOCATION.csv')

# %%
geo_loc.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1041       -23.544392       -46.639499
# 3                         1035       -23.541578       -46.641607
# 4                         1012       -23.547762       -46.635361
#
#   geolocation_city geolocation_state
# 0     Akkarampalle    Andhra Pradesh
# 1     Akkarampalle    Andhra Pradesh
# 2     Akkarampalle    Andhra Pradesh
# 3     Akkarampalle    Andhra Pradesh
# 4     Akkarampalle    Andhra Pradesh

# %%
geo_loc.shape
# Out:
# (19015, 5)

# %%
geo_loc.columns
# Out:
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')

# %%
geo_loc.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  19015.000000     19015.000000     19015.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   42711.591901       -19.062087       -46.058008
# std                    30905.051745         7.319402         5.380751
# min                     1001.000000       -36.605374       -72.927296
# 25%                    12721.500000       -23.564386       -49.000445
# 50%                    38240.000000       -22.429252       -46.632544
# 75%                    70656.500000       -15.615448       -43.255324
# max                    99990.000000        42.184003       121.105394
#
#        geolocation_city geolocation_state
# count             19015             19015
# ...

# %%
geo_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19015 entries, 0 to 19014
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat              19015 non-null  float64
#  2   geolocation_lng              19015 non-null  float64
#  3   geolocation_city             19015 non-null  object
#  4   geolocation_state            19015 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 742.9+ KB

# %%
geo_loc.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %%
geo_loc.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
order_payment = pd.read_csv('ORDER_PAYMENTS.csv')

# %%
order_payment.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payment.shape
# Out:
# (103886, 5)

# %%
order_payment.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
order_payment.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payment.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
order_payment.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_review_rating = pd.read_csv('ORDER_REVIEW_RATINGS.csv')

# %%
order_review_rating.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4       1/18/2018 0:00         1/18/2018 21:46
# 1             5       3/10/2018 0:00          3/11/2018 3:05
# 2             5       2/17/2018 0:00         2/18/2018 14:36
# 3             5       4/21/2017 0:00         4/21/2017 22:02
# 4             5        3/1/2018 0:00          3/2/2018 10:26

# %%
order_review_rating.shape
# Out:
# (100000, 5)

# %%
order_review_rating.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
order_review_rating.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                             100000                            100000
# unique                             99173                             99441
# top     2172867fd5b1a55f98fe4608e1547b4b  03c939fd7fd3b38f8485a0f95798f1f6
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#          review_score review_creation_date review_answer_timestamp
# ...

# %%
order_review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_creation_date     100000 non-null  object
#  4   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
order_review_rating.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
order_review_rating.review_creation_date = pd.to_datetime(order_review_rating.review_creation_date, format='%m/%d/%Y %H:%M')
order_review_rating.review_answer_timestamp = pd.to_datetime(order_review_rating.review_answer_timestamp, format='%m/%d/%Y %H:%M')

# %%
order_review_rating.dtypes
# Out:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
order_review_rating.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
orders = pd.read_csv('ORDERS.csv')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          7/24/2018 20:41    7/26/2018 3:24
# 2    delivered            8/8/2018 8:38     8/8/2018 8:55
# 3    delivered         11/18/2017 19:28  11/18/2017 19:45
# 4    delivered          2/13/2018 21:18   2/13/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              7/26/2018 14:31                8/7/2018 15:27
# ...

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp order_approved_at  \
# count         99441                    99441             99281
# unique            8                    88789             50462
# top       delivered           8/2/2018 12:06   1/10/2018 10:32
# freq          96478                       28               109
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        61544                         75649
# top                  5/9/2018 15:48                2/1/2018 20:29
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
orders.order_purchase_timestamp = pd.to_datetime(orders.order_purchase_timestamp, format='%m/%d/%Y %H:%M')
orders.order_approved_at = pd.to_datetime(orders.order_approved_at, format='%m/%d/%Y %H:%M')
orders.order_delivered_carrier_date = pd.to_datetime(orders.order_delivered_carrier_date, format='%m/%d/%Y %H:%M')
orders.order_delivered_customer_date = pd.to_datetime(orders.order_delivered_customer_date, format='%m/%d/%Y %H:%M')
orders.order_estimated_delivery_date = pd.to_datetime(orders.order_estimated_delivery_date, format='%m/%d/%Y %H:%M')

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
len(orders)*0.05      ## as number of missing rows are less than this number so we can drop them
# Out:
# 4972.05

# %%
orders.dropna(inplace=True)

# %%
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
prod = pd.read_csv('PRODUCTS.csv')

# %%
prod.head()
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             Perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   Art
# 2  96bd76ec8810374ed1b65e291975717f        Sports_Leisure
# 3  cef67bcfe19066a932b7673e239eb23d                  Baby
# 4  9dc1a7de274444849c219cff195d0b71            Housewares
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
prod.shape
# Out:
# (32951, 9)

# %%
prod.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
prod.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32328
# unique                             32951                    71
# top     1e9e8ef04dbcff4541ed26657ea517e5        Bed_Bath_Table
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32328 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
prod.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
prod.isna().sum()
# Out:
# product_id                      0
# product_category_name         623
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
len(prod)*0.05     ## as number of missing rows are less than this number so we can drop them
# Out:
# 1647.5500000000002

# %%
prod.dropna(inplace=True)

# %%
prod.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
seller = pd.read_csv('SELLERS.csv')

# %%
seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix   seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023         Alwal
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13023         Alwal
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031     Badepalle
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195  Akkarampalle
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914       Koratla
#
#      seller_state
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2  Andhra Pradesh
# 3  Andhra Pradesh
# 4  Andhra Pradesh

# %%
seller.shape
# Out:
# (3095, 4)

# %%
seller.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
seller.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix  \
# count                               3095             3095.000000
# unique                              3095                     NaN
# top     3442f8959a84dea7ee197c632cb2df15                     NaN
# freq                                   1                     NaN
# mean                                 NaN            32174.790630
# std                                  NaN            32656.670163
# min                                  NaN             1001.000000
# 25%                                  NaN             7084.000000
# 50%                                  NaN            14940.000000
# 75%                                  NaN            61780.000000
# max                                  NaN            99730.000000
#
#          seller_city    seller_state
# count           3038            3038
# unique           534              19
# top     Akkarampalle  Andhra Pradesh
# ...

# %%
seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3038 non-null   object
#  3   seller_state            3038 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
seller.isna().sum()
# Out:
# seller_id                  0
# seller_zip_code_prefix     0
# seller_city               57
# seller_state              57
# dtype: int64

# %%
len(seller)*0.05     ## as number of missing rows are less than this number so we can drop them
# Out:
# 154.75

# %%
seller.dropna(inplace=True)

# %%
seller.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
order_item = pd.read_csv('ORDER_ITEMS.csv')

# %%
order_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0      9/19/2017 9:45   58.90          13.29
# 1      5/3/2017 11:05  239.90          19.93
# 2     1/18/2018 14:48  199.00          17.87
# 3     8/15/2018 10:10   12.99          12.79
# ...

# %%
order_item.shape
# Out:
# (112650, 7)

# %%
order_item.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
order_item.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_item.shipping_limit_date = pd.to_datetime(order_item.shipping_limit_date, format='%m/%d/%Y %H:%M')

# %%
order_item.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
order_item.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
cust = pd.read_csv('CUSTOMERS.csv')

# %%
cust.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh

# %%
cust.shape
# Out:
# (99441, 5)

# %%
cust.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
cust.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city  customer_state
# ...

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
cust.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
cust.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# ### 1. Perform Detailed exploratory analysis
# #### a. Define & calculate high level metrics like (Total Revenue, Total quantity, Total products, Total categories, Total sellers, Total locations, Total payment methods etc…)

# %% [markdown]
# #### Total Revenue

# %%
order_item.price.sum()
# Out:
# 13591643.700000003

# %% [markdown]
# #### Total Quantity

# %%
len(order_item)
# Out:
# 112650

# %% [markdown]
# #### Total Products

# %%
len(prod)
# Out:
# 32327

# %% [markdown]
# #### Total Product Categories

# %%
prod.product_category_name.nunique()
# Out:
# 71

# %% [markdown]
# #### Total Sellers

# %%
len(seller)
# Out:
# 3038

# %% [markdown]
# #### Total Locations

# %%
geo_loc.geolocation_zip_code_prefix.nunique()
# Out:
# 19015

# %% [markdown]
# #### Total Payment Methods

# %%
order_payment.payment_type.nunique()
# Out:
# 5

# %% [markdown]
# #### Total Customers

# %%
len(cust)
# Out:
# 99441

# %% [markdown]
# ### b. Understanding how many new customers acquired every month

# %%
orders['month_year'] = orders.order_purchase_timestamp.apply(lambda x: pd.Timestamp.strftime(x , format = "%m-%Y"))

# %%
cust_orders = pd.merge(cust , orders , how = 'left' , on= 'customer_id')

# %%
cust_month = cust_orders.loc[:, ['customer_unique_id', 'month_year']]

# %%
cust_month.drop_duplicates(subset='customer_unique_id' , inplace= True)

# %%
new_cust_monthly = cust_month.groupby('month_year')[['customer_unique_id']].count()
new_cust_monthly.head()
# Out:
#             customer_unique_id
# month_year
# 01-2017                    700
# 01-2018                   6834
# 02-2017                   1591
# 02-2018                   6297
# 03-2017                   2464

# %%
new_cust_monthly.plot( kind = 'bar', figsize = (18,5))
plt.ylabel('count of customers')
plt.title('New customers acquired every month')
plt.show()

# %% [markdown]
# ### c. Understand the retention of customers on month on month basis.

# %%
cust_monthly_cnt = cust_orders.groupby('month_year')[['customer_unique_id']].count().reset_index()
cust_monthly_cnt.head()
# Out:
#   month_year  customer_unique_id
# 0    01-2017                 748
# 1    01-2018                7069
# 2    02-2017                1641
# 3    02-2018                6556
# 4    03-2017                2546

# %%
cust_monthly_cnt.customer_unique_id.sum()
# Out:
# 96461

# %%
retented_cust_monthly = pd.merge(new_cust_monthly , cust_monthly_cnt , how= 'left' , on ="month_year")
retented_cust_monthly.head()
# Out:
#   month_year  customer_unique_id_x  customer_unique_id_y
# 0    01-2017                   700                   748
# 1    01-2018                  6834                  7069
# 2    02-2017                  1591                  1641
# 3    02-2018                  6297                  6556
# 4    03-2017                  2464                  2546

# %%
retented_cust_monthly['retented_cust'] = retented_cust_monthly.customer_unique_id_y - retented_cust_monthly.customer_unique_id_x
retented_cust_monthly.head()
# Out:
#   month_year  customer_unique_id_x  customer_unique_id_y  retented_cust
# 0    01-2017                   700                   748             48
# 1    01-2018                  6834                  7069            235
# 2    02-2017                  1591                  1641             50
# 3    02-2018                  6297                  6556            259
# 4    03-2017                  2464                  2546             82

# %%
retented_cust_monthly.plot(kind= 'bar', x= 'month_year' , y = 'retented_cust' , figsize = (16,6))
plt.ylabel('Count of customers')
plt.title('Retention of customers on month on month basis')
plt.show()

# %% [markdown]
# ### d. How the revenues from existing/new customers on month on month basis.

# %%
order_item_month = pd.merge(order_item , orders , how= 'left' , on= 'order_id')

# %%
order_item_month['net_price'] = order_item_month.price + order_item_month.freight_value

# %%
rev_month = order_item_month.groupby('month_year')[['net_price']].sum()
rev_month.head()
# Out:
#              net_price
# month_year
# 01-2017      127367.44
# 01-2018     1077887.46
# 02-2017      269399.65
# 02-2018      966212.50
# 03-2017      414330.95

# %%
rev_month.plot( kind = 'bar', figsize =(16,6))
plt.ylabel('Total Amount')
plt.title('Total Revenue on month on month basis')
plt.show()

# %% [markdown]
# ### e. Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, payment method etc…

# %%
order_items_prod = pd.merge( order_item_month , prod , how ='left' , on = 'product_id')

# %%
order_items_prod['month'] = order_items_prod.order_purchase_timestamp.dt.month
order_items_prod['week'] = order_items_prod.order_purchase_timestamp.dt.to_period('W').dt.week
order_items_prod['day'] = order_items_prod.order_purchase_timestamp.dt.day
order_items_prod['time'] = order_items_prod.order_purchase_timestamp.dt.time

# %%
order_items_prod.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  \
# 0 2017-09-19 09:45:00   58.90          13.29
# 1 2017-05-03 11:05:00  239.90          19.93
# 2 2018-01-18 14:48:00  199.00          17.87
# 3 2018-08-15 10:10:00   12.99          12.79
# ...

# %%
## Trends of sales and quantity by category

cat_qty_sales = order_items_prod.groupby('product_category_name').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
cat_qty_sales
# Out:
#                             quantity       sales
# product_category_name
# Agro_Industry_And_Commerce       212    72530.47
# Air_Conditioning                 297    55024.96
# Art                              209    24202.64
# Arts_And_Craftmanship             24     1814.01
# Audio                            364    50688.50
# ...                              ...         ...
# Stationery                      2517   230943.23
# Tablets_Printing_Image            83     7528.41
# Telephony                       4545   323667.53
# Toys                            4117   483946.60
# Watches_Gifts                   5991  1205005.68
#
# [71 rows x 2 columns]

# %%
cat_qty_sales.quantity.plot(kind='bar',figsize=(15,5))
plt.ylabel('quantity')
plt.title('Trend of Product category by quantity')
plt.show()

# %%
cat_qty_sales.sales.plot(kind='bar',figsize=(15,5))
plt.ylabel('sales')
plt.title('Trend of Product category by sales')
plt.show()

# %%
## Trends of sales and quantity by location

order_items_prod_cust = pd.merge( order_items_prod , cust , how ='left' , on = 'customer_id')

# %%
order_items_prod_cust_loc = pd.merge(order_items_prod_cust, geo_loc , how='left', right_on='geolocation_zip_code_prefix',left_on='customer_zip_code_prefix')

# %%
loc_qty_sales = order_items_prod_cust_loc.groupby('geolocation_state').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
loc_qty_sales
# Out:
#                    quantity       sales
# geolocation_state
# Andhra Pradesh        69647  8088225.37
# Arunachal Pradesh      1102   140245.35
# Chhattisgarh           6604   862409.93
# Delhi                  3543   457829.04
# Goa                       9      695.91
# Gujarat                7842   975661.73
# Haryana                2324   282688.86
# Himachal Pradesh        762    93949.67
# Jammu & Kashmir        1560   189476.58
# Karnataka              4019   485750.40
# Kerala                 1562   189172.62
# Madhya Pradesh         3006   383811.69
# Maharashtra            2118   263388.69
# Orissa                  618    87598.36
# Punjab                  704    85441.95
# Rajasthan               823   113286.99
# Tamil Nadu             2140   279554.71
# Uttar Pradesh          1039   136663.08
# Uttaranchal             102    12623.01
# West Bengal             368    54740.29

# %%
loc_qty_sales.quantity.plot(kind='bar',figsize=(15,5))
plt.ylabel('quantity')
plt.title('Trend of Location by quantity')
plt.show()

# %%
loc_qty_sales.sales.plot(kind='bar',figsize=(15,5))
plt.ylabel('sales')
plt.title('Trend of Location by sales')
plt.show()

# %%
## Trends of sales and quantity by month

month_qty_sales = order_items_prod.groupby('month').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
month_qty_sales
# Out:
#        quantity       sales
# month
# 1.0        8948  1036357.47
# 2.0        9364  1059105.98
# 3.0       10914  1312555.10
# 4.0       10396  1314203.77
# 5.0       11813  1466703.94
# 6.0       10496  1277515.34
# 7.0       11376  1349090.99
# 8.0       11939  1393276.34
# 9.0        4739   607355.64
# 10.0       5533   689188.95
# 11.0       8474   987648.07
# 12.0       6188   726044.09

# %%
month_qty_sales.quantity.plot(kind='bar',figsize=(15,5))
plt.ylabel('quantity')
plt.title('Trend of Month by quantity')
plt.show()

# %%
month_qty_sales.sales.plot(kind='bar',figsize=(15,5))
plt.ylabel('sales')
plt.title('Trend of Month by sales')
plt.show()

# %%
## Trends of sales and quantity by week

week_qty_sales = order_items_prod.groupby('week').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
week_qty_sales
# Out:
#       quantity      sales
# week
# -1        2470  372598.02
#  1        1573  181779.48
#  2        2047  243662.97
#  3        2154  237299.12
#  4        2156  262042.91
#  5        2301  262654.43
#  6        2294  276136.43
#  7        2263  239109.21
#  8        2370  248651.53
#  9        2646  322262.64
#  10       2458  294582.85
#  11       2418  304361.25
#  12       2662  307552.96
#  13       2255  282994.76
#  14       2383  309942.68
#  15       2227  282936.98
#  16       2516  311784.86
#  17       2619  319263.62
#  18       2835  336759.06
#  19       3112  398760.71
#  20       3136  375379.41
#  21       1952  244959.74
#  22       2111  293672.65
#  23       2574  308091.01
#  24       2535  318864.04
#  25       2343  275406.31
#  26       2378  273603.38
#  27       2212  257496.56
#  28       2142  264921.76
#  29       2922  336659.04
#  30       2876  344553.07
#  31       3328  388303.13
#  32       3254  395695.04
#  33       3168  364908.28
# ...

# %%
week_qty_sales.quantity.plot(kind='bar',figsize=(15,5))
plt.ylabel('quantity')
plt.title('Trend of Week by quantity')
plt.show()

# %%
week_qty_sales.sales.plot(kind='bar',figsize=(15,5))
plt.ylabel('sales')
plt.title('Trend of Week by sales')
plt.show()

# %%
## Trends of sales and quantity by day

day_qty_sales = order_items_prod.groupby('day').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
day_qty_sales
# Out:
#       quantity      sales
# day
# 1.0       3412  438275.85
# 2.0       3556  429797.10
# 3.0       3592  442526.73
# 4.0       3776  475544.93
# 5.0       3836  459688.75
# 6.0       3823  466027.22
# 7.0       3695  454909.76
# 8.0       3666  425048.01
# 9.0       3598  450121.68
# 10.0      3454  430930.91
# 11.0      3631  453909.84
# 12.0      3539  422883.55
# 13.0      3646  434979.69
# 14.0      3725  444214.71
# 15.0      3852  463621.13
# 16.0      3983  477809.75
# 17.0      3537  416719.99
# 18.0      3809  481762.19
# 19.0      3795  441024.42
# 20.0      3651  436549.30
# 21.0      3420  382360.85
# 22.0      3603  391760.09
# 23.0      3503  399790.92
# 24.0      4309  502559.91
# 25.0      3663  426777.71
# 26.0      3708  421206.60
# 27.0      3569  413662.04
# 28.0      3323  411211.24
# 29.0      2848  358513.45
# 30.0      2791  328080.03
# 31.0      1867  236777.33

# %%
day_qty_sales.quantity.plot(kind='bar',figsize=(15,5))
plt.ylabel('quantity')
plt.title('Trend of Day by quantity')
plt.show()

# %%
day_qty_sales.sales.plot(kind='bar',figsize=(15,5))
plt.ylabel('sales')
plt.title('Trend of Day by sales')
plt.show()

# %%
## Trend of sales and quantity by payment type

order_items_prod_payment = pd.merge(order_items_prod, order_payment, how='left', on='order_id')

# %%
payment_type_qty_sales = order_items_prod_payment.groupby('payment_type').agg({'product_id':'count','price': 'sum'}).rename(columns={'product_id':'quantity','price':'sales'})
payment_type_qty_sales
# Out:
#               quantity        sales
# payment_type
# UPI              22867   2391525.66
# credit_card      86769  10974357.30
# debit_card        1691    183758.74
# voucher           6274    659473.64

# %%
payment_type_qty_sales.quantity.plot(kind='bar',figsize=(5,5), color='blue')
plt.ylabel('quantity')
plt.title('Trend of Payment type by quantity')
plt.show()

# %%
payment_type_qty_sales.sales.plot(kind='bar',figsize=(5,5), color='blue')
plt.ylabel('sales')
plt.title('Trend of Payment type by sales')
plt.show()

# %% [markdown]
# ### f. Popular Products by month, seller, state, category.

# %%
## Popular product by month

prod_month = order_items_prod.groupby(['month','product_id']).agg({'product_id':'count'}).rename(columns={'product_id':'count'}).reset_index()
prod_month= prod_month.sort_values(by=['month','count']).drop_duplicates(subset='month',keep='last')
prod_month
# Out:
#        month                        product_id  count
# 3026     1.0  aca2eb7d00ea1a7b8ebd4e68314663af    121
# 8801     2.0  e53e557d5a159f5aa2c5e995dfdf244b     71
# 13125    3.0  aca2eb7d00ea1a7b8ebd4e68314663af     65
# 16815    4.0  53b36df67ebb7c41585e8d54d6772e08     84
# 22709    5.0  53b36df67ebb7c41585e8d54d6772e08    114
# 28388    6.0  42a2c92a0979a949ca4ea89ec5c7b934     71
# 36413    7.0  99a4788cb24856965c36a24e339b6058     70
# 45204    8.0  e7cc48a9daff5436f63d3aad9426f28b     64
# 46575    9.0  422879e10f46682990de24d770e7f83d     37
# 49419   10.0  422879e10f46682990de24d770e7f83d     39
# 52856   11.0  422879e10f46682990de24d770e7f83d     91
# 57038   12.0  422879e10f46682990de24d770e7f83d     51

# %%
# Popular product by sellers 

prod_seller = order_items_prod.groupby(['seller_id','product_id']).agg({'product_id':'count'}).rename(columns={'product_id':'count'}).reset_index()
prod_seller= prod_seller.sort_values(by=['seller_id','count']).drop_duplicates(subset='seller_id' ,keep='last')
prod_seller
# Out:
#                               seller_id                        product_id  \
# 0      0015a82c2db000af6aaaf3ae2ecb0532  a2ff5a97bf95719e38ea2e3b4105bce8
# 1      001cca7ae9ae17fb1caed9dfb1094831  08574b074924071f4e201e151b152b4e
# 12     001e6ad469a905060d959994f1b41e4f  093cd981b714bcdff182b427d87fc8fc
# 14     002100f778ceb8431b7a1020ff7ab48f  158102fe543dbaeb84d87811bfe06d0d
# 37     003554e2dce176b5555353e4f3555ac8  67f36b3689147d882d2b298fd0715d80
# ...                                 ...                               ...
# 34388  ffcfefa19b08742c5d315f2791395ee5  cea898bfbca0b5b0e7b36cecd350709e
# 34397  ffdd9f82b9a447f6f8d4b91554cc7dd3  ada800a927673ac73cdfbbd2c832331b
# 34402  ffeee66ac5d5a62fe688b9d26f83f534  1347d4320dcd0acd750e37bb3d94a918
# 34430  fffd5413c0700ac820c7069d66d98c89  ebb12274522d82caa7dca657873b2ad7
# 34444  ffff564a4f9085cd26170f4732393726  dbd024d4182504993ad1e3cd2ee9d9e9
#
#        count
# 0          3
# 1        113
# 12         1
# 14        17
# ...

# %%
## Popular product by state 

prod_state = order_items_prod_cust_loc.groupby(['geolocation_state','product_id']).agg({'product_id':'count'}).rename(columns={'product_id':'count'}).reset_index()
prod_state= prod_state.sort_values(by=['geolocation_state','count']).drop_duplicates(subset='geolocation_state' ,keep='last')
prod_state
# Out:
#        geolocation_state                        product_id  count
# 16279     Andhra Pradesh  aca2eb7d00ea1a7b8ebd4e68314663af    347
# 24243  Arunachal Pradesh  03e1c946c0ddfc58724ff262aef08dff     12
# 26247       Chhattisgarh  422879e10f46682990de24d770e7f83d     38
# 30293              Delhi  53759a2ecddad2bb87a079a1f1519f73     21
# 31996                Goa  dd231637766e756fd1cf2fd80501fce1      1
# 35256            Gujarat  aca2eb7d00ea1a7b8ebd4e68314663af     44
# 37968            Haryana  99a4788cb24856965c36a24e339b6058     11
# 38834   Himachal Pradesh  422879e10f46682990de24d770e7f83d      5
# 39970    Jammu & Kashmir  89b190a046022486c635022524a974a8     15
# 42219          Karnataka  99a4788cb24856965c36a24e339b6058     22
# 44182             Kerala  aca2eb7d00ea1a7b8ebd4e68314663af     11
# 45890     Madhya Pradesh  99a4788cb24856965c36a24e339b6058     17
# 47752        Maharashtra  99a4788cb24856965c36a24e339b6058     13
# ...

# %%
## Popular product by category

prod_cat = order_items_prod.groupby(['product_category_name','product_id']).agg({'product_id':'count'}).rename(columns={'product_id':'count'}).reset_index()
prod_cat= prod_cat.sort_values(by=['product_category_name','count']).drop_duplicates(subset='product_category_name' ,keep='last')
prod_cat
# Out:
#             product_category_name                        product_id  count
# 7      Agro_Industry_And_Commerce  11250b0d4b709fee92441c5f34122aed     22
# 144              Air_Conditioning  98e91d0f32954dcd8505875bb2b42cdb     17
# 218                           Art  4fe644d766c7566dbc46fb851363cb3b    107
# 267         Arts_And_Craftmanship  b9976e9c22fb1540bd71d1bcd2989475      5
# 316                         Audio  db5efde3ad0cc579b130d71c4b2db522     48
# ...                           ...                               ...    ...
# 28425                  Stationery  fb55982be901439613a95940feefd9ee     84
# 28448      Tablets_Printing_Image  6bbe55cf8f85c87b6eebb775a53402f4     33
# 29469                   Telephony  e7cc48a9daff5436f63d3aad9426f28b     93
# 30359                        Toys  880be32f4db1d9f6e2bec38fb6ac23ab     99
# 31447               Watches_Gifts  53b36df67ebb7c41585e8d54d6772e08    323
#
# [71 rows x 3 columns]

# %% [markdown]
# ### g. Popular categories by state, month

# %%
## Popular product category by state 

cat_state = order_items_prod_cust_loc.groupby(['geolocation_state','product_category_name']).agg({'product_category_name':'count'}).rename(columns={'product_category_name':'count'}).reset_index()
cat_state= cat_state.sort_values(by=['geolocation_state','count']).drop_duplicates(subset='geolocation_state' ,keep='last')
cat_state
# Out:
#       geolocation_state product_category_name  count
# 7        Andhra Pradesh        Bed_Bath_Table   7195
# 100   Arunachal Pradesh       Furniture_Decor     99
# 131        Chhattisgarh        Bed_Bath_Table    649
# 227               Delhi         Health_Beauty    316
# 261                 Goa        Sports_Leisure      1
# 269             Gujarat        Bed_Bath_Table    722
# 336             Haryana        Bed_Bath_Table    267
# 392    Himachal Pradesh        Bed_Bath_Table     77
# 443     Jammu & Kashmir        Bed_Bath_Table    142
# 499           Karnataka        Bed_Bath_Table    358
# 587              Kerala         Health_Beauty    125
# 618      Madhya Pradesh        Bed_Bath_Table    304
# 683         Maharashtra        Bed_Bath_Table    209
# 741              Orissa        Bed_Bath_Table     72
# 814              Punjab         Health_Beauty     70
# 879           Rajasthan        Sports_Leisure     83
# 917          Tamil Nadu         Health_Beauty    187
# ...

# %%
## Popular product category by month

cat_month = order_items_prod.groupby(['month','product_category_name']).agg({'product_category_name':'count'}).rename(columns={'product_category_name':'count'}).reset_index()
cat_month= cat_month.sort_values(by=['month','count']).drop_duplicates(subset='month' ,keep='last')
cat_month
# Out:
#      month  product_category_name  count
# 6      1.0         Bed_Bath_Table    882
# 81     2.0  Computers_Accessories   1071
# 138    3.0         Bed_Bath_Table   1056
# 206    4.0         Bed_Bath_Table   1007
# 275    5.0         Bed_Bath_Table   1101
# 342    6.0         Bed_Bath_Table   1133
# 409    7.0         Bed_Bath_Table   1186
# 512    8.0          Health_Beauty   1187
# 545    9.0         Bed_Bath_Table    528
# 610   10.0         Bed_Bath_Table    550
# 675   11.0         Bed_Bath_Table    961
# 740   12.0         Bed_Bath_Table    546

# %% [markdown]
# ### h. List top 10 most expensive products sorted by price.

# %%
order_items_prod[['product_id','price']].drop_duplicates(subset='product_id' ).sort_values(by='price',ascending = False).head(10)
# Out:
#                               product_id    price
# 3556    489ae2aa008f021502940f251d4cce7f  6735.00
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  6729.00
# 107841  1bdf5e6731585cf01aa8169c7028d6ad  6499.00
# 74336   a6492cc69376c469ab6f61d8f44de961  4799.00
# 11249   c3ed642d592594bb648ff4a04cee2747  4690.00
# 62086   259037a6a41845e455183f89c5035f18  4590.00
# 29193   a1beef8f3992dbd4cd8726796aa69c53  4399.87
# 45843   6cdf8fc1d741c76586d8b6b15e9eef30  4099.99
# 59137   6902c1962dd19d540807d0ab8fade5c6  3999.90
# 56663   4ca7b91a31637bd24fb8e559d5e015e4  3999.00

# %% [markdown]
# ## 2. Performing Customers/sellers Segmentation

# %% [markdown]
# ### a. Divide the customers into groups based on the revenue generated

# %%
cust_order_item = pd.merge(cust_orders , order_item , how ='inner', on= 'order_id' )
cust_order_item.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# ...

# %%
cust_order_item['net_price'] = cust_order_item.price + cust_order_item.freight_value

# %%
cust_rev = cust_order_item[['customer_id','net_price']].groupby('customer_id').sum().sort_values(by='net_price')

# %%
cust_rev['rev_range'] = pd.cut(cust_rev.net_price, bins=[0,100,500,1500,5000,7000,15000],labels=['0-100','100-500','500-1500','1500-5000','5000-7000','7000-15000'])

# %%
cust_rev.head()
# Out:
#                                   net_price rev_range
# customer_id
# a790343ca6f3fee08112d678b43aa7c5       9.59     0-100
# 184e8e8e48937145eb96c721ef1f0747      10.07     0-100
# 8e4bd65db637116b6b68109e4df21b84      10.89     0-100
# 046f890135acc703faff4c1fc0c2d73c      11.56     0-100
# d2c63ad286e3ca9dd69218008d61ff81      11.62     0-100

# %% [markdown]
# ### b. Divide the sellers into groups based on the revenue generated

# %%
seller_rev = order_item[['seller_id','price']].groupby('seller_id').sum().sort_values('price')

# %%
seller_rev['rev_range'] = pd.cut(seller_rev.price, bins=[0,100,5000,20000,100000,300000],labels=['0-100','100-5000','5000-20000','20000-100000','100000-300000'])

# %%
seller_rev.head()
# Out:
#                                   price rev_range
# seller_id
# cf6f6bc4df3999b9c6440f124fb2f687    3.5     0-100
# 77128dec4bec4878c37ab7d6169d6f26    6.5     0-100
# 1fa2d3def6adfa70e58c276bb64fe5bb    6.9     0-100
# 702835e4b785b67a084280efca355756    7.6     0-100
# 34aefe746cd81b7f3b23253ea28bef39    8.0     0-100

# %% [markdown]
# ## 3. Cross-Selling (Which products are selling together)
# ### Hint: We need to find which of the top 10 combinations of products are selling together in each transaction (combination of 2 or 3 buying together)

# %%
orders_order_items = pd.merge(orders , order_item , how='left' , on='order_id' )
orders_order_items.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 2    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 3    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
# 4    delivered      2018-02-13 21:18:00 2018-02-13 22:20:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
cross_selling = orders_order_items[orders_order_items.duplicated(['order_purchase_timestamp','customer_id'],keep=False)].sort_values(by='order_purchase_timestamp')

# %%
cross_selling = cross_selling.loc[:,['customer_id','order_purchase_timestamp','product_id' ]]

# %%
cross_selling.drop_duplicates(subset ="product_id" ,inplace=True)

# %%
cross_selling = cross_selling[cross_selling.duplicated(['order_purchase_timestamp','customer_id'],keep=False)].sort_values(by='order_purchase_timestamp').reset_index()

# %%
cross_selling.drop(columns = 'index',axis=1, inplace=True)

# %%
cross_selling
# Out:
#                            customer_id order_purchase_timestamp  \
# 0     a0f95ab56c6d3a5ba0036b7fdfeda07f      2016-10-04 15:02:00
# 1     a0f95ab56c6d3a5ba0036b7fdfeda07f      2016-10-04 15:02:00
# 2     00474d2582fd72663036795b7ab8cfc1      2016-10-04 22:33:00
# 3     00474d2582fd72663036795b7ab8cfc1      2016-10-04 22:33:00
# 4     3f6f000d5b0a959f38481fad4ab7cac2      2016-10-04 23:59:00
# ...                                ...                      ...
# 3522  72a366446dd3abfc90c598896714d85c      2018-08-26 11:02:00
# 3523  e5a8aaccb766e00177b0a587979cc814      2018-08-26 11:44:00
# 3524  e5a8aaccb766e00177b0a587979cc814      2018-08-26 11:44:00
# 3525  c24bbeb8111fea27eab791a37e665210      2018-08-27 12:39:00
# 3526  c24bbeb8111fea27eab791a37e665210      2018-08-27 12:39:00
#
#                             product_id
# 0     79938780eb7ffb7289f59a9a283bc06b
# 1     8f1e43e0e3374ed8c84df748034d6179
# 2     dc82d7e8f99966cb4c641f7ea5590eaf
# ...

# %% [markdown]
# ## 4. Payment Behaviour

# %% [markdown]
# ### a. How customers are paying?

# %%
order_payment.payment_type.unique()
# Out:
# array(['credit_card', 'UPI', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %% [markdown]
# ### b. Which payment channels are used by most customers?

# %%
cust_orders_payment = pd.merge(cust_orders, order_payment, how='left', on='order_id')

# %%
cust_orders_payment[['payment_type','customer_id']].groupby('payment_type').count().reset_index()
# Out:
#   payment_type  customer_id
# 0          UPI        19177
# 1  credit_card        74584
# 2   debit_card         1485
# 3      voucher         5493

# %%
plt.figure(figsize=(3,3))
cust_orders_payment[['payment_type','customer_id']].groupby('payment_type').count().plot(kind='pie',subplots=True)
plt.ylabel(' ')
plt.show()

# %% [markdown]
# ## 5. Customer satisfaction towards category & product

# %% [markdown]
# ### a. Which categories (top 10) are maximum rated & minimum rated?

# %%
order_review_rating
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# ...

# %%
order_item
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_item_rating = pd.merge(order_review_rating,order_item,how='inner',on='order_id')

# %%
prod_order_item_rating = pd.merge(order_item_rating, prod, how='inner', on='product_id')

# %%
prod_order_item_rating
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       e2655da8bccce2ddc2f43cc2c80d24f3  19721d59a9764437477eff0730b48665
# 3       cb18f53b563f0bdeb76be0376ddd6b6a  efd626e6a12a82d76e456e34093f8356
# 4       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# ...                                  ...                               ...
# 111680  7047578adefcc7c27319e3cf91ba1416  01da5549f136167573c8a302f008557a
# 111681  7e42a39bc8cf4d1eb5897cb48c2889f7  287445be3e2a5f0d3f5036b2a778d1c5
# 111682  586e77c5f02b95285a939083359f8241  5f4a120717a4d152577d7d2ec66c45be
# 111683  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 111684  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
#
#         review_score review_creation_date review_answer_timestamp  \
# ...

# %%
prod_order_item_rating[['review_score','product_category_name']].groupby('product_category_name').sum().sort_values('review_score',ascending=False).head(10)
# Out:
#                        review_score
# product_category_name
# Bed_Bath_Table                43636
# Health_Beauty                 40121
# Sports_Leisure                35616
# Furniture_Decor               32716
# Computers_Accessories         30953
# Housewares                    28235
# Watches_Gifts                 24016
# Telephony                     17907
# Garden_Tools                  17572
# Auto                          17193

# %%
prod_order_item_rating[['review_score','product_category_name']].groupby('product_category_name').sum().sort_values('review_score').head(10)
# Out:
#                                    review_score
# product_category_name
# Security_And_Services                         5
# Fashion_Childrens_Clothes                    36
# La_Cuisine                                   53
# Cds_Dvds_Musicals                            65
# Arts_And_Craftmanship                        99
# Home_Comfort_2                              101
# Diapers_And_Hygiene                         127
# Fashion_Sport                               132
# Flowers                                     139
# Furniture_Mattress_And_Upholstery           145

# %% [markdown]
# ### b. Which products (top10) are maximum rated & minimum rated?

# %%
prod_order_item_rating[['review_score','product_id']].groupby('product_id').sum().sort_values('review_score',ascending=False).head(10)
# Out:
#                                   review_score
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af          2112
# 422879e10f46682990de24d770e7f83d          1920
# 99a4788cb24856965c36a24e339b6058          1896
# 389d119b48cf3043d311335e499d9c6b          1612
# 368c6c730842d78016ad823897a372db          1531
# 53759a2ecddad2bb87a079a1f1519f73          1448
# d1c427060a0f73f6b889a5c7c61f2ac4          1432
# 53b36df67ebb7c41585e8d54d6772e08          1348
# 154e7e31ebfa092203795c972e5804a6          1264
# 3dd2a17168ec895c781a9191c1e95ad7          1147

# %%
prod_order_item_rating[['review_score','product_id']].groupby('product_id').sum().sort_values('review_score').head(10)
# Out:
#                                   review_score
# product_id
# 7f47a78f50b93196e945ec522b6e6788             1
# 541de21b45fa18d292382c79394e055c             1
# b33250fb5abd199c0bff38eb1db5bc7b             1
# b32ca9d6896d74d345424426815c06a7             1
# b32a26b904950912fc8f6c1f88019d1b             1
# 54209aa243cdc7067e4a8e75bcef44f8             1
# 5421431a9abfbdac3006e7aa925c0213             1
# b2a40530065c5d88115cfa7560151794             1
# b29c1749f99da888ea322a01420d5220             1
# b27653c33039497c46ceba21db46a43c             1

# %% [markdown]
# ### c. Average rating by location, seller, product, category, month etc.

# %%
order_review_ratings2 = pd.merge(orders, order_review_rating, on='order_id' , how='left')
order_review_ratings2 = pd.merge(order_review_ratings2, cust, on='customer_id' , how='left')
order_review_ratings2 = pd.merge(order_review_ratings2, order_item, on='order_id' , how='left')
order_review_ratings2.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 2    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 3    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
# 4    delivered      2018-02-13 21:18:00 2018-02-13 22:20:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
## Average rating by location

avg_rating_location = order_review_ratings2.groupby('customer_state')['review_score'].mean().reset_index()
avg_rating_location.rename(columns={'customer_state':'Location', 'review_score':'Avg_review'}, inplace =True)
avg_rating_location
# Out:
#              Location  Avg_review
# 0      Andhra Pradesh    4.051137
# 1   Arunachal Pradesh    4.075758
# 2        Chhattisgarh    4.080302
# 3               Delhi    4.079305
# 4                 Goa    4.800000
# 5             Gujarat    4.083602
# 6             Haryana    4.140016
# 7    Himachal Pradesh    4.037667
# 8     Jammu & Kashmir    4.056615
# 9           Karnataka    4.063481
# 10             Kerala    4.088915
# 11     Madhya Pradesh    4.049247
# 12        Maharashtra    4.114324
# 13             Orissa    4.132836
# 14             Punjab    4.183424
# 15          Rajasthan    4.137387
# 16         Tamil Nadu    4.147576
# 17      Uttar Pradesh    4.173369
# 18        Uttaranchal    3.698113
# 19        West Bengal    4.034063

# %%
## Average rating by seller

avg_rating_seller = order_review_ratings2.groupby('seller_id')['review_score'].mean().reset_index()
avg_rating_seller.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_seller
# Out:
#                              seller_id  Avg_review
# 0     0015a82c2db000af6aaaf3ae2ecb0532    3.666667
# 1     001cca7ae9ae17fb1caed9dfb1094831    3.935897
# 2     002100f778ceb8431b7a1020ff7ab48f    4.036364
# 3     003554e2dce176b5555353e4f3555ac8    5.000000
# 4     004c9cd9d87a3c30c522c48c4fc07416    4.114943
# ...                                ...         ...
# 2965  ffc470761de7d0232558ba5e786e57b7    4.300000
# 2966  ffdd9f82b9a447f6f8d4b91554cc7dd3    4.250000
# 2967  ffeee66ac5d5a62fe688b9d26f83f534    4.214286
# 2968  fffd5413c0700ac820c7069d66d98c89    3.931034
# 2969  ffff564a4f9085cd26170f4732393726    3.250000
#
# [2970 rows x 2 columns]

# %%
order_review_ratings2['month'] = order_review_ratings2.review_answer_timestamp.dt.month

# %%
## Average rating by month

avg_rating_month = order_review_ratings2.groupby('month')['review_score'].mean().reset_index()
avg_rating_month.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_month
# Out:
#     month  Avg_review
# 0       1    4.005284
# 1       2    4.030860
# 2       3    3.809866
# 3       4    3.896666
# 4       5    4.146607
# 5       6    4.128883
# 6       7    4.228210
# 7       8    4.224123
# 8       9    4.219526
# 9      10    4.122647
# 10     11    4.083223
# 11     12    3.897335

# %% [markdown]
# ## 6. State with maximum number of customers.

# %%
cust[['customer_state','customer_id']].groupby('customer_state').count().sort_values('customer_id',ascending=False)
# Out:
#                    customer_id
# customer_state
# Andhra Pradesh           60688
# Gujarat                   7467
# Chhattisgarh              6355
# Karnataka                 3866
# Delhi                     3332
# Madhya Pradesh            2853
# Haryana                   2202
# Tamil Nadu                2122
# Maharashtra               2005
# Jammu & Kashmir           1537
# Kerala                    1531
# Arunachal Pradesh         1119
# Uttar Pradesh             1033
# Rajasthan                  808
# Himachal Pradesh           743
# Punjab                     679
# Orissa                     625
# West Bengal                369
# Uttaranchal                 97
# Goa                         10
